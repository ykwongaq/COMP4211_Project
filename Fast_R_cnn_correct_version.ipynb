# %% [markdown]
# Link to our model weight

# %%
https://drive.google.com/file/d/1-AGcx7YEeZnbslnRi5LtuUWZsqiCiP7r/view?usp=sharing

# %%
import time
import os
import random
import math

import torch
import torchvision
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import Dataset
from torch.optim import lr_scheduler
from torch.autograd import Variable
from torchvision import transforms, models
from PIL import Image
from torch.utils.tensorboard import SummaryWriter
# from sklearn.model_selection import KFold
# from tqdm.auto import tqdm
from scipy import ndimage
import pickle
import logging
import torchvision.models as models
# %matplotlib inline

# %%
assert os.environ['COLAB_GPU'], 'Make sure to select GPU from Edit > Notebook settings > Hardware accelerator'
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !rm -f data
# !ln -s '/content/drive/MyDrive/proj2_data' data

# %% [markdown]
# ### Utilities for Herarchical Grouping Algorithm
#
# - `extractextractImgbyRoI(img, Coords)`:
#
#   Crop the image base on the given Coordinates
#
# - `constructNeighbourGrid()`
#
#   Construct the Neighbour Grid. In this project, the neighbour grid is a 100-by-100 matrix
#
# - `initCoord()`
#
#   Divide the image into 10*10 regions. It resturns the coordinates `(x_min, y_min, x_max, y_max)` of those regions
#
# - `initRegions()`
#
#   Initialize the output RoIs. It return a set that contain the ID of initial 100 regions. Set is used so that element can join the set easily
#
# - `regionsToCoord(Coords, Regions)`
#
#   Base on the given regions ID `Regions`, return the corresponding coordinates `(x_min, y_min, x_max, y_max)` of that regions
#
# - `getHist(img)`
#
#   Gernerate the histrogram for the given image `img`.
#
# - `sim(region1, region2)`
#
#   Calculate the similarity of two given regions of image.
#
# - `findNeighbour(regions, size)`
#
#   Base on the given regions ID, find it's neighbour. It return the ID of it's neighbour regions. In this project, `size` is 10
#
# - `tuple2list(input)`
#
#   Convert the given list of tuple and integers to a list without tuple. The input list usually contain a mixture of tuple and integer. This fucntion extract the element in the tuple to form a list together with other integers
#
# - `removeEnclosedRegion(regions, newR)`
#
#   Remove the region in `regions` that already covered by `newR`. In other word, it remove all the subset of `newR`
#
#   If `regions = [(1, 2), (3, 4)]` and `newR = (1, 2, 5)`, the result will be `[(1, 2, 5), (3, 4)]`
#
#
# - `cropRect(ROIs, regions)`
#
#     Since the regions after merging may not be a rectangle, this function will crop the smallest rectangle that contain the regions. The output is the coordinate of those the smalles rectangles

# %% [markdown]
# #### Hierachical Grouping Algorithm
#
# - `genRoIsperImg(im, size)`
#
# `im`: the input image
# `size`: how many regions to be devided for initialization. If `size` is 10, then 10\*10 reisons will be initialized
#
# Procedures:
# 1. Regions initialization using `initCoord` and `initRegions`. In this project, 10\*10 regions are initialized
# 2. Generate the similarity grid for each nearby regions. similarity grid is a 100\*100 matrix for this project. For example, s(r_1, r_2) store the value of similarity of r_1 and r_2. If r_1 and r_2 are not neighbour, the value will be `np.NaN`
# 3. Merge the regions with highest similarity and calculate the similarities again
# 4. Continue until the image left with one region

# %%
def collate_fn1(batch):
    return tuple(zip(*batch))

def imshow(img, gt_box, turb_type,pred_box=None,VMIN=0.77):#vmin is the minimum color threhold, since our color too light, we should increase the vmin
    img=np.uint8(img*255)
    PIL_img=transforms.ToPILImage()(img).convert('RGB')
    grayscale_image = PIL_img.convert("L")
    grayscale_array = np.asarray(grayscale_image)/255
    print(grayscale_array.shape)
    imgplot = plt.imshow(grayscale_array, cmap="gray",vmin=VMIN)
    
    def draw_box(box, turb_type):
        x1, y1, x2, y2 = box
        if x1 == 0:
            x1 = 1
        if y1 == 0:
            y1 = 1
        if x2 >= 840:
          x2 = 839
        if y2 >= 840:
          y2 = 839
        if turb_type==2:
          color='red'
        else:
          color='green'
        plt.gca().add_patch(
            plt.Rectangle((x1, y1), x2-x1, y2-y1,
                          fill=False, edgecolor=color, linewidth=2, alpha=0.5)
        )
    for i in range(len(gt_box)):
      draw_box(gt_box[i],turb_type[i])
    if pred_box is not None:
        draw_box(pred_box, 'blue')
    plt.plot()

def to_2d_tensor(inp):
    inp = torch.Tensor(inp)
    if len(inp.size()) < 2:
        inp = inp.unsqueeze(0)
    return inp

def box_transform_inv(boxes, im_sizes):
    # box in (x, y, w, h) format
    boxes = to_2d_tensor(boxes)
    im_sizes = to_2d_tensor(im_sizes)
    boxes[:, 0] = (boxes[:, 0] + 1) / 2 * im_sizes[:, 0]
    boxes[:, 1] = (boxes[:, 1] + 1) / 2 * im_sizes[:, 1]
    boxes[:, 2] = boxes[:, 2] / 2 * im_sizes[:, 0]
    boxes[:, 3] = boxes[:, 3] / 2 * im_sizes[:, 1]
    return boxes

def box_transform(boxes, im_sizes):
    # box in (x, y, w, h) format
    boxes = to_2d_tensor(boxes)
    im_sizes = to_2d_tensor(im_sizes)
    boxes[:, 0] = 2 * boxes[:, 0] / im_sizes[:, 0] - 1
    boxes[:, 1] = 2 * boxes[:, 1] / im_sizes[:, 1] - 1
    boxes[:, 2] = 2 * boxes[:, 2] / im_sizes[:, 0]
    boxes[:, 3] = 2 * boxes[:, 3] / im_sizes[:, 1]
    return boxes

def xywh_to_x1y1x2y2(boxes):
    boxes = to_2d_tensor(boxes)
    boxes[:, 2] += boxes[:, 0] - 1
    boxes[:, 3] += boxes[:, 1] - 1
    return boxes

def x1y1x2y2_to_xywh(boxes):
    boxes = to_2d_tensor(boxes)
    boxes[:, 2] -= boxes[:, 0] - 1
    boxes[:, 3] -= boxes[:, 1] - 1
    return boxes

def compute_IoU(boxes1, boxes2):
    boxes1 = to_2d_tensor(boxes1)
    boxes2 = to_2d_tensor(boxes2)

    
    intersec = boxes1.clone()
    intersec[:, 0] = torch.max(boxes1[:, 0], boxes2[:, 0])
    intersec[:, 1] = torch.max(boxes1[:, 1], boxes2[:, 1])
    intersec[:, 2] = torch.min(boxes1[:, 2], boxes2[:, 2])
    intersec[:, 3] = torch.min(boxes1[:, 3], boxes2[:, 3])
    
    def compute_area(boxes):
        # in (x1, y1, x2, y2) format
        dx = boxes[:, 2] - boxes[:, 0]
        dx[dx < 0] = 0
        dy = boxes[:, 3] - boxes[:, 1]
        dy[dy < 0] = 0
        return dx * dy
    
    a1 = compute_area(boxes1)
    a2 = compute_area(boxes2)
    ia = compute_area(intersec)
    assert((a1 + a2 - ia <= 0).sum() == 0)
    
    return ia / (a1 + a2 - ia)    

def compute_acc(preds, targets, theta=0.75):
    IoU = compute_IoU(preds.clone(), targets.clone())
    corr = (IoU >= theta).sum()
    return corr.item() / preds.size(0)

class AverageMeter(object):
    def __init__(self):
        self.reset()
        
    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.cnt = 0
        
    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.cnt += n
        self.avg = self.sum / self.cnt
        
def box_to_mask(box, im_size):
    mask = np.zeros(im_size)
    co = xywh_to_x1y1x2y2(box)[0].type(torch.int64)
    mask[co[0]: co[2], co[1]: co[3]] = 1
    return Image.fromarray(np.uint8(mask*255).T)

def mask_to_box(mask):
    mask = torch.nonzero(mask[0, :, :].T != 0, as_tuple=False)
    x1, y1 = torch.min(mask, dim=0).values
    x2, y2 = torch.max(mask, dim=0).values
    return x1y1x2y2_to_xywh([x1, y1, x2, y2])[0]

#### ROI_PROPOSAL_ALGORITHM
def extractImgbyRoI(img, Coords):
  (x_min, y_min, x_max, y_max) = Coords[0]
  result = img[:, y_min:y_max, x_min:x_max]
  for i in range(1, len(Coords)):
    (x_min, y_min, x_max, y_max) = Coords[i]
    result = np.concatenate((result, img[:, y_min:y_max, x_min:x_max]), axis=2)
  return np.array(result)

def myImgShow(img):
  img = img.transpose((1, 2, 0))/255
  #img = img.numpy().transpose((1, 2, 0))/255
  plt.imshow(img)

def constructNeighbourGrid():
  size = 10
  neighbourGrid = []
 
  for i in range(size):
    for j in range(size):
      background = np.zeros((10, 10))
      #background[i][j] = 1
      # Dilation
      if i-1 >= 0: background[i-1][j] = 1
      if i+1 < size: background[i+1][j] = 1
      if j-1 >= 0: background[i][j-1] = 1
      if j+1 < size: background[i][j+1] = 1

      background = background.flatten()
      neighbourGrid.append(background == 1)

  return np.array(neighbourGrid)

def initCoord(img, size):
  _, h, w = img.shape
  sub_h, sub_w = math.floor(h/size), math.floor(w/size)
  RoIs = np.array([[[j*sub_w, i*sub_h, (j+1)*sub_w-1, (i+1)*sub_h-1] for j in range(size)] for i in range(size)])
  RoIs = RoIs.reshape(size*size, 4)
  return RoIs
    

def initRegions(size):
  return set([(i) for i in range(size)])


def regionsToCoord(Coords, regions):
  regions_list = tuple2list(regions)
  res = Coords[regions_list[0]].reshape(1, 4)
  for i in range(1, len(regions_list)):
    res = np.concatenate((res, Coords[regions_list[i]].reshape((1, 4))))
  return res


def regionsToCoord_test(Coords, regions):
  print(regions)
  regions_list = tuple2list(regions)
  print(regions_list[0])
  print(Coords[regions_list[0]].reshape(1, 4))
  res = Coords[regions_list[0]].reshape(1, 4)
  for i in range(1, len(regions_list)):
    res = np.concatenate((res, Coords[regions_list[i]].reshape((1, 4))))
  return res


def getHist(img):
  D, _, _ = img.shape
  histogram = []
  for channel_idx in range(D):
    h, _ = np.histogram(img[channel_idx, :, :], bins=25)
    histogram = histogram + list(h)
  histogram = np.array(histogram/np.linalg.norm(histogram, 1))
  return histogram

def sim(region1, region2):
  histogram1 = getHist(region1)
  histogram2 = getHist(region2)

  sim = np.vstack((histogram1, histogram2))
  sim = np.amin(sim, 0)
  sim = sim.sum()

  return sim

def findNeighbour(regions, size):
  neighbourGrid = np.zeros((size*size, 1))
  neighbourGrid[tuple2list(regions)] = 1
  neighbourGrid = neighbourGrid.reshape((size, size))
  neighbourGrid = ndimage.binary_dilation(neighbourGrid).astype(neighbourGrid.dtype)
  neighbourGrid = neighbourGrid.reshape((size*size, 1))
  neighbourGrid[tuple2list(regions)] = 0
  return np.where(neighbourGrid == 1)[0]

def tuple2list(input):
  if type(input) == int:
    return [input]
  res = []
  for element in input:
    if type(element) == tuple:
      res = res + list(element)
    else:
      res.append(element)
  return res

def removeEnclosedRegion(regions, newR):
  redundance = set()
  for t in regions:
    if set(t).issubset(newR):
      redundance.add(t)

  regions.symmetric_difference_update(redundance)
  return regions

def cropRect(RoIs, regions):
  res = RoIs
  for region in regions:
    coords = regionsToCoord(RoIs, region)

    coord_max = np.amax(coords, axis=0)
    coord_min = np.amin(coords, axis=0)

    vector = [coord_min[0], coord_min[1], coord_max[2], coord_max[3]]
    res = np.vstack((res, vector))

  return np.array(res)

# %%
def genRoIsperImg(im, size): 
  RoIs = initCoord(im, size)
  regions = initRegions(size*size)

  neighbourGrid = constructNeighbourGrid()

  simGrid = set()
  for i in range(size*size):
    for j in range(i, size*size):
      if neighbourGrid[i][j]:
        img1 = extractImgbyRoI(im, regionsToCoord(RoIs, [i]))
        img2 = extractImgbyRoI(im, regionsToCoord(RoIs, [j]))
        simGrid.add((i, j, sim(img1, img2)))

  regions_merged = set()
  current_merged_regions = set()
  i = 0
  while len(simGrid) > 0:
  #for i in range(20):
    # print('itr#:', i, " with size= ", len(simGrid))
    i = i+1
    region1, region2, _ = max(simGrid, key=lambda x:x[2])
    #print("region1 = ", region1)
    #print("region2 = ", region2)
    newRegion = set()
    newRegion.update(tuple2list(region1))
    newRegion.update(tuple2list(region2))
    regions_merged.add(tuple(newRegion))
    current_merged_regions = removeEnclosedRegion(current_merged_regions, tuple(newRegion))
    current_merged_regions.add(tuple(newRegion))
    removeList = list(filter(lambda x: x[0] == region1 or x[1] == region1, simGrid))
    #print("remove one = ", removeList)
    c1 = len(removeList)
    simGrid.difference_update(removeList)
    removeList = list(filter(lambda x: x[0] == region2 or x[1] == region2, simGrid))
    #print("remove two = ", removeList)
    c1 = c1 + len(removeList)
    #print("no of removal = ", c1)
    simGrid.difference_update(removeList)

    neighbourRegions = findNeighbour(newRegion, 10)
    #print("neigbour regions = ", neighbourRegions)
    for j in range(len(neighbourRegions)):
      neighbourRegion = neighbourRegions[j]
      #print("==== current neibh = ", neighbourRegion)
      counted = False
      for region in filter(lambda x: neighbourRegion in x, current_merged_regions):
        #print("region = ", region)
        counted = True
        img1 = extractImgbyRoI(im, regionsToCoord(RoIs, newRegion))
        img2 = extractImgbyRoI(im, regionsToCoord(RoIs, region))
        #print("add: ", (tuple(newRegion), region, sim(img1, img2)))
        simGrid.add((tuple(newRegion), region, sim(img1, img2)))

      if counted:
        #print(neighbourRegion, ' is counted')
        continue

      for region in filter(lambda x:x==neighbourRegion, regions):
        #print("single region = ", region)
        img1 = extractImgbyRoI(im, regionsToCoord(RoIs, newRegion))
        img2 = extractImgbyRoI(im, regionsToCoord(RoIs, [region]))
        #print("add: ", (tuple(newRegion), region, sim(img1, img2)))
        simGrid.add((tuple(newRegion), region, sim(img1, img2)))

    if len(simGrid) <= 0:
      break
  
  res = cropRect(RoIs, regions_merged)
  res = set([tuple(ele) for ele in res])
  res = np.array(list(res))
  # print("finish")
  return res
    #print(regions_merged)
    #print(len(simGrid))

# %% [markdown]
# ## define dataset

# %% [markdown]
#     # MyDataset.prepare function calculate and store all the data needed for each image
#     # data includes image itself, ground truth roi, ground truth class labels and proposed rois of each image
#     # each element inside rois list is a tuple with first element being the coordinate of this roi in the foramte of (x1,y1,x2,y2)
#     # Second element within the tuple is a dictionary that store the information of this specific RoI
#     #{
#     #  roi_dict = {
#     #          "gt_box_iou_score": most_likely_gt_box_iou_score, ==> the iou score
#     #          "gt_index": most_likely_gt_index,
#     #          "gt_box_coord": gt_box_coord,
#     #          "gt_box_coord_xywh": gt_box_coord_xywh,
#     #          "gt_box_class": gt_box_class
#     #      }
#     #}

# %%
class MyDataset(Dataset):
    def __init__(self, datatype='train', transform=None):
        with open('data/bbox_'+datatype+'.csv') as f:
            id_to_box = dict()
            id_to_path = dict()
            id_to_turb= dict()
            last_name='none'
            idx=-1
            for line in f.read().splitlines():
                filename, wid, hei, turb, *box = line.split(',') # get all variable
                if turb =='severe turbulence':
                  turb_no=2
                else:
                  turb_no=1
                if filename == 'filename': # skip the title
                  continue

                if filename==last_name:
                  id_to_box[idx].append(list(map(float, box)))
                  id_to_turb[idx].append(turb_no)
                  
                else:
                  idx=idx+1
                  id_to_path[idx]=filename
                  id_to_box[idx]=[list(map(float, box))]
                  id_to_turb[idx]=[turb_no]
                  last_name=filename

            self.imgs = [(os.path.join('data/'+datatype, id_to_path[i]), id_to_box[i],id_to_turb[i])
                     for i in range(len(id_to_path))]

            #transform data
            self.target_transform = transforms.Compose([
                transforms.Resize((840, 840)),
                transforms.ToTensor()
            ])
            self.transform = transforms.Compose([
                self.target_transform,
                transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
            ])
            if transform is not None:
                self.transform = transforms.Compose([
                    transform,
                    self.transform
                ])
                self.target_transform = transforms.Compose([
                    transform,
                    self.target_transform
                ])
                
    #Added by Shih-Yang,LIU
    #This prepare function calculate and store all the data needed for each image
    # data includes image itself, ground truth roi, ground truth class labels and proposed rois of each image
    # each element inside rois list is a tuple with first element being the coordinate of this roi in the foramte of (x1,y1,x2,y2)
    # Second element within the tuple is a dictionary that store the information of this specific RoI
    #{
    #  roi_dict = {
    #          "gt_box_iou_score": most_likely_gt_box_iou_score, ==> the iou score 
    #          "gt_index": most_likely_gt_index,
    #          "gt_box_coord": gt_box_coord,
    #          "gt_box_coord_xywh": gt_box_coord_xywh,
    #          "gt_box_class": gt_box_class
    #      }
    #}
    def prepare_data(self):
      

      self.data = []
      img_count = 1
      for img in self.imgs:
        # if img_count == 5:
        #   break
        print("processing image#: ", img_count)
        img_count = img_count+1
        path, box, turb = img
        im = (np.load(path))/292*255
        im=np.transpose(im,(1, 2, 0))
        im=np.uint8(im)
        boxes = np.array(box, dtype='int32')
        seed = np.random.randint(2147483647)
        random.seed(seed)
        torch.manual_seed(seed)
        PIL = transforms.ToPILImage()(im).convert('RGB')#if you want to output 4 dimension data, change to .convert('RGBA'). While you will not able to do transforms.Normalize()
        im = self.target_transform(PIL)

        v = genRoIsperImg(im, 10)


        proposed_roi_lable = []
        for i in v:
          IoU_list = []
          for gt_box in box:
            IoU = compute_IoU(i, gt_box)
            IoU_list.append(IoU)
          most_likely_gt_box_iou_score = max(IoU_list)
          most_likely_gt_index = IoU_list.index(most_likely_gt_box_iou_score)
          gt_box_coord = box[most_likely_gt_index]
          if most_likely_gt_box_iou_score > 0:
            gt_box_class = turb[most_likely_gt_index]
          else:
            gt_box_class = 0

          gt_box_coord_xywh = np.array([gt_box_coord[0],gt_box_coord[1],gt_box_coord[2]-gt_box_coord[0],gt_box_coord[3]-gt_box_coord[1]])
          if(gt_box_coord_xywh[2]==0):
            print(gt_box_coord)



          roi_dict = {
              "gt_box_iou_score": most_likely_gt_box_iou_score,
              "gt_index": most_likely_gt_index,
              "gt_box_coord": gt_box_coord,
              "gt_box_coord_xywh": gt_box_coord_xywh,
              "gt_box_class": gt_box_class
          }

          proposed_roi_lable.append([i,roi_dict])

        self.data.append([im, box, turb, proposed_roi_lable])

          # print(most_likely_gt_box_iou_score, most_likely_gt_index, gt_box_coord, gt_box_class)




    def __getitem__(self, index):
      return self.data[index]

    def __len__(self):
        return len(self.imgs)

# %%
# val=MyDataset(datatype='val', transform=None)
# val.prepare_data()
# torch.save(val,'/content/data/val.pt')

# %%
# test=MyDataset(datatype='test', transform=None)
# test.prepare_data()
# torch.save(train,'/content/data/test.pt')

# %%
train = torch.load('/content/data/train.pt')
val = torch.load('/content/data/val.pt')

# %%
test = torch.load('/content/data/test.pt')

# %%
train_dataloader = torch.utils.data.DataLoader(train,batch_size=2,shuffle=False,collate_fn=collate_fn1)
val_dataloader = torch.utils.data.DataLoader(val,batch_size=2,shuffle=False,collate_fn=collate_fn1)

# %%
test_dataloader = torch.utils.data.DataLoader(test,batch_size=2,shuffle=False,collate_fn=collate_fn1)

# %% [markdown]
# ## minibatch sampling
#
# Mini_batch_sampling follow the procedures mentioned in the paper.
#
# Procedures:
# 1. First determine the rois that have the IoU score above or equal to 0.5 and mark them as positive
# 2. Determine the rois that have the IoU score above or equal to 0.1 and below 0.5 and mark them as negative
# 3. If portion = 0.5, then select 0.5 of the total number of positive rois as output
# 4. Then add the negative rois to make sure the number of output rois are the same as the give size `size`
# 5. Variable `new` determine how to select positive rois. If `True`, it will select the portion of rois with max. iou scoure. If `False`, it will select the rois with min. iou score

# %%
# False -> Use old sampling method
# True -> Use new sampling method
def mini_batch_sampling(rois, size, portion, new=False):
  res = []
  if new:
    for roi in rois:
      # Extract ious scoure from dictionary
      roi = np.array(roi, dtype=object)
      dictionaries = roi[:, 1]
      ious = list(map(lambda x:x.get('gt_box_iou_score').item(), dictionaries))
      ious = np.array(ious)

      # Find the locaiton grid for postive label and negative label
      posLocation = (ious >= 0.5).astype(int)
      negLocation = ((ious >= 0.1)*(ious < 0.5)).astype(int)

      # Calculate the 
      posCount = np.sum(posLocation)
      no_of_pos_needed = math.floor(posCount*portion) if posCount*portion <= size else size
      no_of_neg_needed = size - no_of_pos_needed

      outputIdx = []

      # Extract pos index
      if no_of_pos_needed > 0:
        temp_ious = ious.copy()
        temp_ious[(1-posLocation).astype(bool)] = -1
        pos_idx = np.argpartition(temp_ious, -no_of_pos_needed)[-no_of_pos_needed:]
        #print(pos_idx)
        outputIdx = outputIdx + list(pos_idx)
      
      if no_of_neg_needed > 0:
        ious[(1-negLocation).astype(bool)] = -1
        neg_idx = np.argpartition(ious, -no_of_neg_needed)[-no_of_neg_needed:]
        outputIdx = outputIdx + list(neg_idx)

      res.append(outputIdx)
  else:
    for roi in rois:
      # Extract ious scoure from dictionary
      roi = np.array(roi, dtype=object)
      dictionaries = roi[:, 1]
      ious = list(map(lambda x:x.get('gt_box_iou_score').item(), dictionaries))
      ious = np.array(ious)

      #print(ious)

      # Find the locaiton grid for postive label and negative label
      posLocation = (ious >= 0.3).astype(int)
      negLocation = ((ious >= 0.1)*(ious < 0.3)).astype(int)

      # Calculate the 
      posCount = np.sum(posLocation)
      print("cosCount = ", posCount)
      no_of_pos_needed = math.floor(posCount*portion) if posCount*portion <= size else size
      no_of_neg_needed = size - no_of_pos_needed


      
      outputIdx = []

      # Extract pos index
      pos_idx = np.where(posLocation == 1)[0]

      random_select = np.random.choice(pos_idx, size = no_of_pos_needed)
      # print(no_of_pos_needed)
      outputIdx = outputIdx + list(random_select)
      # outputIdx = outputIdx + list(pos_idx[0:no_of_pos_needed])


      if no_of_neg_needed > 0:
        ious[(1-negLocation).astype(bool)] = -1
        # neg_idx = np.argpartition(ious, -no_of_neg_needed)[-no_of_neg_needed:]
        neg_idx = np.argpartition(ious, -no_of_neg_needed)
        random_select = np.random.choice(neg_idx, size = no_of_neg_needed)

        outputIdx = outputIdx + list(random_select)

      #print("negative and positive output = ", len(outputIdx))
      res.append(outputIdx)
  return res

# %% [markdown]
# ## Fast R CNN Model

# %% [markdown]
# *   _smooth_l1_loss: for calculating smooth L1 Loss that was specified in the paper "Fast R-cnn" for calculating the loss for BBOX regression
# *   fast_rcnn_loc_loss: This function is to tackle the way how Fast Rcnn calculate location loss. Fast Rcnn only need to calculate losses for ground truth label larger than 1, in another words, doesn't need to take consider background class.
# *    normal_init: In the paper, it states the fully connected layers used for softmax classification and bounding-box regression are initialized from zero-mean Gaussian distributions with stan- dard deviations 0.01 and 0.001. And This function tackle this problem.

# %% [markdown]
# *   Fast Rcnn
# *   The Conv layer is extracted from the torchvision.model.Alexnet, and I we tested wether to use pretrined model based on ImageNet or not. We found out that using non pretrained model resulted in lower loss.
# *   The roi pooling layers was built by using torchvision.ops.roi_pool with conv_feature_map and the proposed_roi as input to do the Roi projection. Final RoI feature vector is fixed in our porject with size (C,13,13)
# *   After getting the Roi pooling result vectors for each Roi, we feed them into a fully connected layers with three linear layers and dropout layers in between them, and also a Relu to provide non linearity.
# - We then use the obtained RoI Feature vectors to feed into three different fully connected networks for calculating the following three information
#     - One for getting the likelihood of each class
#     - One for modeling the coordinate of the identified object in the format (x,y,w,h) which is P in the below image
#     - One for learning the weight D for the BBox regression, that will transform P into g_hat like below.
# <br>
#
# The Fast R cnn will have 4 outputs
# *   Approximation probability of each class
# *   The identified object location coordinate
# *   P weighting for calculating T
# *   D weighting for calculating T
# *   T is the target transformation

# %% [markdown]
# ![WhatsApp Image 2020-12-22 at 3.51.32 PM.jpeg](data:image/jpeg;base64,...)

# %%
def _smooth_l1_loss(x, t, in_weight, sigma):

    sigma2 = sigma ** 2
    diff = in_weight * (x - t)
    abs_diff = diff.abs()
    flag = (abs_diff.data < (1. / sigma2)).float()
    y = (flag * (sigma2 / 2.) * (diff ** 2) +
         (1 - flag) * (abs_diff - 0.5 / sigma2))
    return y.sum()

# %%
def fast_rcnn_loc_loss(pred_loc, gt_loc, gt_label, sigma):
    in_weight = torch.zeros(gt_loc.shape).cuda()
    # Localization loss is calculated only for positive rois.
    # NOTE:  unlike origin implementation, 
    # we don't need inside_weight and outside_weight, they can calculate by gt_label
    in_weight[(gt_label > 0).view(-1, 1).expand_as(in_weight).cuda()] = 1
    loc_loss = _smooth_l1_loss(pred_loc, gt_loc, in_weight.detach(), sigma)
    # # Normalize by total number of negtive and positive rois.
    loc_loss /= ((gt_label >= 0).sum().float()) # ignore gt_label==-1 for rpn_loss
    return loc_loss

# %%
def normal_init(m, mean, stddev, truncated=False):
    """
    weight initalizer: truncated normal and random normal.
    """
    # x is a parameter
    if truncated:
        m.weight.data.normal_().fmod_(2).mul_(stddev).add_(mean)  # not a perfect approximation
    else:
        m.weight.data.normal_(mean, stddev)
        m.bias.data.zero_()

# %%
class Fast_R_cnn(nn.Module):
  def __init__(self, roi_size, scaling_factor, rois_per_image,pretrained=True):
    super(Fast_R_cnn, self).__init__()
    self.roi_size = roi_size
    self.scaling_factor = scaling_factor
    alexnet = models.alexnet(pretrained=pretrained)
    #structure of alexnet could be modified if performance is bad
    self.alexnet = nn.Sequential(*list(alexnet.children())[:-2])
    self.alexnet[0][12]=nn.Identity() 

    self.ROI_pooling_layer = torchvision.ops.roi_pool
    self.rois_per_image = rois_per_image


    ## FCs to produced ROI feature vectors
    self.ROI_head = nn.Sequential(
      nn.Linear(in_features=43264, out_features=21632, bias=True),
      nn.ReLU(inplace=True),
      nn.Dropout(p=0.5, inplace=False),
      nn.Linear(in_features=21632, out_features=10816, bias=True),
      nn.ReLU(inplace=True),
      nn.Linear(in_features=10816, out_features=3000, bias=True),
      nn.ReLU(inplace=True)
    )

    n_class = 2
    ## FCs for softmax 
    self.classficiation_label = nn.Sequential(
      nn.Linear(3000, 3, bias=True), #Because 3 classes
      nn.Softmax()
    )

    ## FCs for bbox regressor 
    self.fc_before_regressor = nn.Sequential(
      nn.Linear(3000, 4, bias=True),
      nn.ReLU(inplace=True)
    )

    ## input using pool5 fectures and output for weigths for the bounding box calculation
    self.regressor = nn.Sequential(
      nn.Linear(3000, 4,bias=True)
    )

    normal_init(self.regressor[0], 0, 0.001)
    normal_init(self.classficiation_label[0], 0, 0.01)





  def forward(self, images_data, roi_list, batch_size):

    conv_feature_map = self.alexnet(images_data)
    # print(conv_feature_map.shape)

    proposed_roi = roi_list

    roi_pooling_result = self.ROI_pooling_layer(input = conv_feature_map, boxes= proposed_roi, output_size = self.roi_size, spatial_scale= self.scaling_factor)

    # print(roi_pooling_result.shape)


    roi = torch.reshape(roi_pooling_result, (batch_size*self.rois_per_image,43264))


    # #ROI feature vector size (2*#roi,3000)
    ROI_feature = self.ROI_head(roi)

    # # Classification label 
    result_labels_probabilities = self.classficiation_label(ROI_feature)


    # # BBOX Regresor
    # # Let bk = (bkx,bky,bkh,bkw) be the output for class k (k = 1,2) from the FC layer just before the bbox regressor in Figure 2
    p = self.fc_before_regressor(ROI_feature)
    

    d_k = self.regressor(ROI_feature)

    d_k_xy = d_k[:,0:2]
    d_k_wh = d_k[:,2:4]
    d_k_wh_exponential = torch.exp(d_k_wh)

    new_d_k = torch.cat([d_k_xy, d_k_wh_exponential],1)
    
    # (x,y,w,h)
    p_wh_1 = p[:,2:4] 

    p_w_h =  torch.cat([p_wh_1,p_wh_1], 1)

    g_hat = p_w_h*new_d_k



    g_hat[:,0:2] = g_hat[:,0:2] + p[:,0:2]

    
    return result_labels_probabilities, g_hat, p, d_k

# %% [markdown]
# ## Training process

# %% [markdown]
# EarlyStopping is to end the Training process earlier if validation loss hasn't decrease for a pre defined number of epoch.
# Model will be automatically save for a predetermined amount of time. For example 25 epoch, 50 epoch, 100 epochs.

# %%
class EarlyStopping:
    def __init__(self, patience=7, verbose=False):
        """
        Args:
            patience (int): How long to wait after last time validation loss improved.
                            Default: 7
            verbose (bool): If True, prints a message for each validation loss improvement. 
                            Default: False
        """
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.save_counter = 1
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.fileName = "checkpoint.tar"

    def __call__(self, val_loss, model, epoch, save_path):

        if(self.save_counter == 25 or self.save_counter == 50 or self.save_counter == 75 or self.save_counter == 100):
          self.save_checkpoint(val_loss, model, epoch, save_path)

        score = -val_loss
        self.save_counter += 1

        if self.best_score is None:
            self.best_score = score

        elif score <= self.best_score:
           # validation lost didn't decrease
            self.counter += 1
            print(
                f'EarlyStopping counter: {self.counter} out of {self.patience}'
            )
            if self.counter >= self.patience:
                self.early_stop = True
        else:
          # validation lost decrease
            self.best_score = score
            self.counter = 0
    
    def save_checkpoint(self, val_loss, model, epoch, save_path):
        '''Saves model when validation loss decrease.'''
        if self.verbose:
            print(
                f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...'
            )
        torch.save(model, os.path.join(save_path, self.fileName))
        self.val_loss_min = val_loss

# %%
def train(model, weight_decay, earlystopping_patience, run_dir, save_dir, new_roi_proposal=False): #run dir is for tensorboard save_dir is for saving model

    save_dir = save_dir
    run_dir = run_dir 
    if not os.path.isdir(run_dir):
        os.makedirs(run_dir)
    tb = SummaryWriter(run_dir)
    # initialize the early_stopping object
    early_stopping = EarlyStopping(patience=earlystopping_patience, verbose=True)



    if os.path.exists(os.path.join(save_dir, 'checkpoint.pth.tar')):
        # load existing model
        print('==> loading existing model')
        model_info = torch.load(os.path.join(save_dir, 'checkpoin.pth.tar'))
        model.load_state_dict(model_info['state_dict'])
        optimizer = torch.optim.Adam(model.parameters())
        optimizer.load_state_dict(model_info['optimizer'])
        cur_epoch = model_info['epoch'] + 1
    else:
        if not os.path.isdir(save_dir):
            os.makedirs(save_dir)
        cur_epoch = 0


    optimizer = optim.SGD(model.parameters(),lr=LR, weight_decay=weight_decay)
    pla_lr_scheduler = lr_scheduler.ReduceLROnPlateau(optimizer,
                                                      factor=0.5,
                                                      patience=2,
                                                      verbose=True)
    
    # to track the training loss as the model trains
    train_losses = []
    # to track the validation loss as the model trains
    valid_losses = []
    # to track the average training loss per epoch as the model trains
    avg_train_losses = []
    # to track the average validation loss per epoch as the model trains
    avg_valid_losses = []

    for epoch in range(cur_epoch, EPOCHS + 1):
        ###################
        # train the model #
        ###################

        current_epoch_loss = []

        for data in train_dataloader:
  
          imgs, boxes, turbs, rois = data

          imgs_tensor = torch.zeros([len(imgs),3,840,840])


          for i in range(len(imgs)):
            imgs_tensor[i] = imgs[i]

          roi_index_list = mini_batch_sampling(rois, model.rois_per_image, 0.5, new_roi_proposal) 



          gt_roi_labels = torch.ones([len(roi_index_list)*model.rois_per_image]) #20 = batch*rois_per_image
          gt_roi_coord = torch.ones([len(roi_index_list)*model.rois_per_image,4])

          roi_list = torch.ones([len(roi_index_list)*model.rois_per_image,5], dtype=torch.float32) 
          for i in range(len(roi_index_list)):
            for j in range(len(roi_index_list[i])):
              roi_list[i*model.rois_per_image+j,:] = torch.tensor(np.insert(rois[i][roi_index_list[i][j]][0], 0, i))
              gt_roi_labels[i*model.rois_per_image+j] = torch.tensor(rois[i][roi_index_list[i][j]][1]["gt_box_class"])

              x1y1x2y2 = torch.tensor(rois[i][roi_index_list[i][j]][1]["gt_box_coord"])

              x1y1wh = torch.tensor([x1y1x2y2[0],x1y1x2y2[1],x1y1x2y2[2]-x1y1x2y2[0],x1y1x2y2[3]-x1y1x2y2[1]])
              gt_roi_coord[i*model.rois_per_image+j] = x1y1wh


          imgs_tensor = imgs_tensor.cuda()
          roi_list = roi_list.cuda()
          gt_roi_labels = gt_roi_labels.cuda()
          gt_roi_coord = gt_roi_coord.cuda()

                
          optimizer.zero_grad()
          model.train()
          result_class_score, result_coord, p_value, d_value = model(images_data = imgs_tensor, roi_list= roi_list, batch_size = len(roi_index_list))

          classfication_loss = nn.CrossEntropyLoss()(result_class_score, gt_roi_labels.long())

          eps=1e-7
          t_xy = gt_roi_coord-p_value
          t_xy_diff_with_gt = t_xy[:,[0,1]]

          p_wh = p_value[:,[2,3]]
          t_xy = torch.div(t_xy_diff_with_gt, p_wh+eps)


          gt_wh = gt_roi_coord[:,[2,3]]

          t_wh = torch.div(gt_wh,p_wh+eps)

          t_wh_log = torch.log(t_wh)
          
          t_xywh = torch.cat([t_xy,t_wh_log],1)
  



          loc_loss = fast_rcnn_loc_loss(d_value, t_xywh, gt_roi_labels, 1)


          total_loss = classfication_loss+loc_loss
          print("total_loss: ",total_loss)
          # break 

          total_loss.backward()
          torch.nn.utils.clip_grad_value_(model.parameters(), clip_value=10.0)
          optimizer.step()
          
          loss_avg = total_loss.item()/BATCH_SIZE
          current_epoch_loss.append(loss_avg)
          train_losses.append(loss_avg)

        loss_avg_epoch = sum(current_epoch_loss) / len(current_epoch_loss)
        print('epoch: %i \t loss_aver: %f'%(epoch, loss_avg_epoch))
        

        tb.add_scalar('TrainLoss', loss_avg_epoch, epoch)
        ######################
        # validate the model #
        ######################
        with torch.no_grad():
          model.eval()

          for data in val_dataloader:
    
            imgs, boxes, turbs, rois = data

            imgs_tensor = torch.ones([len(imgs),3,840,840])


            for i in range(len(imgs)):
              imgs_tensor[i] = imgs[i]

            ###########################
            #mini batch sampling(rois)#
            ###########################

            roi_index_list = mini_batch_sampling(rois, model.rois_per_image, 0.5, new_roi_proposal) #==> have bug "index out of range"

            gt_roi_labels = torch.ones([len(roi_index_list)*model.rois_per_image]) #20 = batch*rois_per_image
            gt_roi_coord = torch.ones([len(roi_index_list)*model.rois_per_image,4])

            roi_list = torch.ones([len(roi_index_list)*model.rois_per_image,5], dtype=torch.float32) 
            for i in range(len(roi_index_list)):
              # roi_per_image = torch.zeros([10,4], dtype=torch.float32) 
              for j in range(len(roi_index_list[i])):
                roi_list[i*model.rois_per_image+j,:] = torch.tensor(np.insert(rois[i][roi_index_list[i][j]][0], 0, i))
                gt_roi_labels[i*model.rois_per_image+j] = torch.tensor(rois[i][roi_index_list[i][j]][1]["gt_box_class"])

                x1y1x2y2 = torch.tensor(rois[i][roi_index_list[i][j]][1]["gt_box_coord"])

                x1y1wh = torch.tensor([x1y1x2y2[0],x1y1x2y2[1],x1y1x2y2[2]-x1y1x2y2[0],x1y1x2y2[3]-x1y1x2y2[1]])
                # print(x1y1wh)
                gt_roi_coord[i*model.rois_per_image+j] = x1y1wh
    

            imgs_tensor = imgs_tensor.cuda()
            roi_list = roi_list.cuda()
            gt_roi_labels = gt_roi_labels.cuda()
            gt_roi_coord = gt_roi_coord.cuda()

            result_class_score, result_coord, p_value, d_value = model(images_data = imgs_tensor, roi_list= roi_list, batch_size = len(roi_index_list))

            # # print(result_coord.shape)

            classfication_loss = nn.CrossEntropyLoss()(result_class_score, gt_roi_labels.long())

            eps=1e-7
            t_xy = gt_roi_coord-p_value
            t_xy_diff_with_gt = t_xy[:,[0,1]]

            p_wh = p_value[:,[2,3]]
            t_xy = torch.div(t_xy_diff_with_gt, p_wh+eps)

            
            gt_wh = gt_roi_coord[:,[2,3]]
            t_wh = torch.div(gt_wh,p_wh+eps)
            t_wh_log = torch.log(t_wh)
            # print("t_wh_log: ",t_wh_log[0])

            t_xywh = torch.cat([t_xy,t_wh_log],1)
            # print("t_xywh:",t_xywh)



            loc_loss = fast_rcnn_loc_loss(d_value, t_xywh, gt_roi_labels, 1)

            total_loss = classfication_loss+loc_loss

            
            loss_avg = total_loss.item()/BATCH_SIZE

            valid_losses.append(loss_avg)

          print('epoch: %i \t valid_loss_aver: %f'%(epoch, loss_avg))

        tb.add_scalar('ValidLoss', loss_avg, epoch)
        torch.cuda.empty_cache()
        # print training/validation statistics
        # calculate average loss over an epoch
        train_loss = np.average(train_losses)
        valid_loss = np.average(valid_losses)
        avg_train_losses.append(train_loss)
        avg_valid_losses.append(valid_loss)

        epoch_len = len(str(EPOCHS))

        print_msg = (f'[{epoch:>{epoch_len}}/{EPOCHS:>{epoch_len}}] ' +
                     f'train_loss: {train_loss:.6f} ' +
                     f'valid_loss: {valid_loss:.6f}')

        #print(print_msg)
        # clear lists to track next epoch
        train_losses = []
        valid_losses = []
        pla_lr_scheduler.step(valid_loss)  # lr_scheduler
        model_dict = {
            'epoch': epoch,
            'state_dict': model.state_dict(),
            'optimizer': optimizer.state_dict()
        }
        early_stopping(valid_loss.item(), model_dict, epoch, save_dir)
        if early_stopping.early_stop:
            print("Early stopping")
            break

# %% [markdown]
# ## Testing process

# %%
def test_process(model, new_roi_proposal=False):

    test_model = model
    
    test_model.cuda()

    # to track the testing loss 
    valid_losses = []

    with torch.no_grad():
        test_model.eval()

        for data in test_dataloader:
  
          imgs, boxes, turbs, rois = data

          imgs_tensor = torch.zeros([len(imgs),3,840,840])


          for i in range(len(imgs)):
            imgs_tensor[i] = imgs[i]

          ###########################
          #mini batch sampling(rois)#
          ###########################
          roi_index_list = mini_batch_sampling(rois,model.rois_per_image, 0.5, new_roi_proposal) 

          gt_roi_labels = torch.ones([2*model.rois_per_image]) #20 = batch*rois_per_image
          gt_roi_coord = torch.ones([2*model.rois_per_image,4])
          gt_roi_coord_xy = torch.ones([2*model.rois_per_image,4])

          roi_list = torch.zeros([2*model.rois_per_image,5], dtype=torch.float32) 
          for i in range(len(roi_index_list)):
            for j in range(len(roi_index_list[i])):
              roi_list[i*model.rois_per_image+j,:] = torch.tensor(np.insert(rois[i][roi_index_list[i][j]][0], 0, i))
              gt_roi_labels[i*model.rois_per_image+j] = torch.tensor(rois[i][roi_index_list[i][j]][1]["gt_box_class"])

              x1y1x2y2 = torch.tensor(rois[i][roi_index_list[i][j]][1]["gt_box_coord"])
              x1y1wh = torch.tensor([x1y1x2y2[0],x1y1x2y2[1],x1y1x2y2[2]-x1y1x2y2[0],x1y1x2y2[3]-x1y1x2y2[1]])
              gt_roi_coord[i*model.rois_per_image+j] = x1y1wh



          imgs_tensor = imgs_tensor.cuda()
          roi_list = roi_list.cuda()
          gt_roi_labels = gt_roi_labels.cuda()
          gt_roi_coord = gt_roi_coord.cuda()

          result_class_score, result_coord, p_value, d_value = test_model(images_data = imgs_tensor, roi_list= roi_list, batch_size = len(roi_index_list))

          classfication_loss = nn.CrossEntropyLoss()(result_class_score, gt_roi_labels.long())

          eps=1e-7
          t_xy = gt_roi_coord-p_value
          t_xy_diff_with_gt = t_xy[:,[0,1]]

          p_wh = p_value[:,[2,3]]
          t_xy = torch.div(t_xy_diff_with_gt, p_wh+eps)

          
          gt_wh = gt_roi_coord[:,[2,3]]
          t_wh = torch.div(gt_wh,p_wh+eps)
          t_wh_log = torch.log(t_wh)
          # print("t_wh_log: ",t_wh_log[0])

          t_xywh = torch.cat([t_xy,t_wh_log],1)

          loc_loss = fast_rcnn_loc_loss(d_value, t_xywh, gt_roi_labels, 1)
          total_loss = classfication_loss+loc_loss

          loss_avg = total_loss.item()/BATCH_SIZE
          print("loss_avg_this_batch: ",loss_avg)
          valid_losses.append(loss_avg)

          #Calculaing average IoU of this images'roi
          total_count = model.rois_per_image*2
          correct_class = 0


          iou_score_list = []
          for roi_index, roi_identify_coord in enumerate(result_coord):
            identified_class = torch.argmax(result_class_score[roi_index])
            ground_truth_class = gt_roi_labels[roi_index]
            if(ground_truth_class!=0):
              print("identified_roi", roi_identify_coord)
              print("identified_roi_class", identified_class)
              print("ground_truth_xywh", gt_roi_coord[roi_index])
              print("ground_truth_class: ", ground_truth_class)


            if(identified_class == ground_truth_class):
              correct_class = correct_class + 1
              if(ground_truth_class != 0):
                roi_xy = torch.tensor([roi_identify_coord[0],roi_identify_coord[1],roi_identify_coord[0]+roi_identify_coord[2],roi_identify_coord[1]+roi_identify_coord[3]])  
                iou_score = compute_IoU(roi_xy,gt_roi_coord_xy[roi_index])
                print("iou_score: ", iou_score)
                iou_score_list.append(iou_score)

          try:
            iou_avg_score = sum(iou_score_list) / len(iou_score_list) 
            avg_correct_class = correct_class/total_count
            print("iou_avg_score %f %%" % float(float(sum(iou_score_list) / len(iou_score_list))*100))
            print("avg_correct_class %f %%" % float(float(correct_class/total_count)*100))
          except:
            print("skip no iou identified")
            
    torch.cuda.empty_cache()
    valid_loss = np.average(valid_losses)
    print('loss_aver: %f'%(valid_loss))

# %% [markdown]
# ## main()

# %% [markdown]
# This is the Hyperparameters to fine tuned

# %%
BATCH_SIZE = 2 #DoN'T CHANGE NO ENOUGH GPU 
EPOCHS = 100
LR = 0.001
WEIGHT_DECAY = 0.001
EARLY_STOPPING_PATIENCE = 6 #EPOCHS
NEW_ROI_PROPOSAL = False
PRE_TRAIN = False

# %%
model = Fast_R_cnn(roi_size=13,scaling_factor=float(51/840),rois_per_image=20,pretrained=PRE_TRAIN)
model.cuda()

# optimizer = optim.SGD(model.parameters(),lr=LR)
# Out:
# Fast_R_cnn(
#   (alexnet): Sequential(
#     (0): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#       (1): ReLU(inplace=True)
#       (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (4): ReLU(inplace=True)
#       (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (7): ReLU(inplace=True)
#       (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (9): ReLU(inplace=True)
#       (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (11): ReLU(inplace=True)
#       (12): Identity()
#     )
#   )
#   (ROI_head): Sequential(
#     (0): Linear(in_features=43264, out_features=21632, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=21632, out_features=10816, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Linear(in_features=10816, out_features=3000, bias=True)
#     (6): ReLU(inplace=True)
#   )
#   (classficiation_label): Sequential(
#     (0): Linear(in_features=3000, out_features=3, bias=True)
#     (1): Softmax(dim=None)
#   )
#   (fc_before_regressor): Sequential(
#     (0): Linear(in_features=3000, out_features=4, bias=True)
#     (1): ReLU(inplace=True)
#   )
#   (regressor): Sequential(
#     (0): Linear(in_features=3000, out_features=4, bias=True)
#   )
# )

# %%
run_dir = '/content/data/run/Sean_train_3/' 
save_dir = '/content/data/model/Sean_train_3/'

# %% [markdown]
# ### HYPER PARAMETERS (CAN BE CHANGED)

# %%
train(model=model, weight_decay=WEIGHT_DECAY, earlystopping_patience=EARLY_STOPPING_PATIENCE, run_dir=run_dir, save_dir=save_dir, new_roi_proposal=NEW_ROI_PROPOSAL)

torch.save(model, "/content/data/model/Sean_train_3/auto_save.tar")
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/container.py:117: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# 串流輸出內容已截斷至最後 5000 行。
# total_loss:  tensor(3.7826, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(5.5741, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(7.7108, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(2.9535, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(3.3988, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(3.1221, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(3.6255, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(3.5726, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(2.7884, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.7214, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(2.3633, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(3.6192, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(2.5204, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.7585, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.3028, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.5183, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(2.7021, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(3.5353, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(3.4108, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(3.8149, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(3.6592, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(2.6442, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(2.9266, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(2.0937, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(2.7170, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.5187, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.4998, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.3372, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.3508, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(2.3908, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(2.4970, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(2.6532, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(3.2485, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(2.1809, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(2.6121, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.7888, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.3453, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.4725, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.7619, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.7081, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.6087, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.4590, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.7282, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.4344, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(3.0373, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.6995, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(2.2679, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(2.3731, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(3.0798, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(3.3875, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(2.8486, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(3.3523, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(3.0268, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(3.3631, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(3.6167, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(2.2392, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.3898, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(2.2238, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.4382, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(2.2457, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.8232, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(2.1320, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.7731, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.9815, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(2.3724, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.7971, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.9582, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(2.3252, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.5353, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.2245, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.2111, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.1655, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.7920, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(2.0912, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(2.4026, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(2.3638, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(3.6075, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(2.6745, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.4898, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(3.2881, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(2.8659, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(3.4209, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(2.2258, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(3.1681, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.5617, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.8108, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(3.3246, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(4.9124, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.7926, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(2.7931, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(3.3125, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(2.7322, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.2548, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.1306, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.8095, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.8994, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.4441, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.5285, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.5681, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.6486, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(2.3768, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.5963, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.2802, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(2.6279, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(2.6954, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(2.7044, device='cuda:0', grad_fn=<AddBackward0>)
# epoch: 18 	 loss_aver: 1.270535
# epoch: 18 	 valid_loss_aver: 0.993795
# total_loss:  tensor(2.9577, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(2.1304, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(2.1098, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(2.0851, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(2.8220, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(2.9309, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(2.6794, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(2.5760, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(2.5711, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(2.6432, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(2.4735, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(2.0786, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(3
device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.6095, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.7940, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.4640, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.7222, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.3709, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.5618, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.4844, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.3726, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(0.9573, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(0.8468, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(0.9561, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.2837, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.1358, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.6485, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.6105, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.5175, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.4139, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.3005, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.0790, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(0.8920, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(0.8717, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.0068, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(0.9290, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(0.7603, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(0.9854, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.0814, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.3250, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(0.8456, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(0.9277, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.4699, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(0.9864, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.1072, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.1920, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.3084, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.3252, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.2397, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.6560, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.4652, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.0239, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(0.9791, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.0359, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(0.9486, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.1335, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.4449, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.4364, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.3981, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.5373, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.5513, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.8764, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.6075, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.5647, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.5790, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.5499, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.6445, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.4218, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.4469, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(0.8474, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(0.8710, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(0.8767, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(0.7016, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(0.9168, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.1041, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.0783, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.5410, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.1817, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.2196, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.4537, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.6935, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.4658, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.0287, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(0.8728, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.3793, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.0006, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.2347, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.1773, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.2459, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.3200, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.2395, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(0.9309, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(0.9557, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(0.9784, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.2086, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.0916, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(0.8954, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(0.9514, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.0581, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.1842, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.3503, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.2241, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.2206, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.0438, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.3796, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.2730, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.0804, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(0.8414, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(0.9388, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(0.8594, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.0537, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.2637, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.1905, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.3080, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.3303, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.1921, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(0.8564, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.2881, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.1370, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.0356, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.3973, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.4700, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.2045, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.3442, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.0456, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(0.9460, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.1905, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.2886, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.0354, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.1426, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.1672, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.1143, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.1852, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.0253, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.0616, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.0673, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.2091, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.1709, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.0511, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(0.9939, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(0.7973, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(0.9610, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(0.9917, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(0.9243, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(0.9055, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(0.8545, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(0.7502, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(0.8010, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(0.7661, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(0.8391, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(0.7890, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.0431, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.1398, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.0413, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.0408, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(0.9939, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(0.9084, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(0.9972, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.0130, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.0013, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.1510, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(0.9171, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(0.9861, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.9135, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.6466, device='cuda:0', grad_fn=<AddBackward0>)
# total_loss:  tensor(1.6638, device='cuda:0', grad_fn=<AddBackward0>)
# epoch: 41 	 loss_aver: 0.614522

# %%
count = 0
for data in train_dataloader:
  
          imgs, boxes, turbs, rois = data

          imgs_tensor = torch.zeros([len(imgs),3,840,840])


          for i in range(len(imgs)):
            imgs_tensor[i] = imgs[i]

          ###########################
          #mini batch sampling(rois)#
          ###########################
          roi_index_list = mini_batch_sampling(rois,10, 1, False) 
          print(roi_index_list)
          count += 1
          if count == 8:
           break
# Out:
# cosCount =  6
# cosCount =  2
# [[12, 12, 89, 89, 161, 161, 150, 96, 81, 74], [59, 154, 91, 52, 155, 45, 117, 75, 27, 162]]
# cosCount =  4
# cosCount =  4
# [[10, 118, 118, 118, 95, 135, 46, 136, 155, 177], [26, 26, 146, 26, 1, 116, 107, 38, 62, 43]]
# cosCount =  5
# cosCount =  7
# [[43, 70, 155, 81, 70, 6, 134, 64, 57, 121], [8, 141, 0, 76, 149, 8, 0, 1, 11, 125]]
# cosCount =  2
# cosCount =  5
# [[127, 127, 124, 79, 118, 60, 118, 62, 104, 27], [8, 87, 88, 150, 27, 78, 82, 89, 74, 162]]
# cosCount =  7
# cosCount =  7
# [[164, 72, 53, 34, 38, 38, 108, 31, 124, 38], [138, 37, 37, 37, 65, 139, 37, 143, 10, 14]]
# cosCount =  16
# cosCount =  10
# [[14, 132, 35, 35, 103, 142, 21, 0, 156, 0], [50, 119, 168, 107, 50, 73, 12, 12, 107, 54]]
# cosCount =  6
# cosCount =  7
# [[19, 19, 29, 152, 19, 2, 110, 41, 16, 59], [76, 131, 166, 129, 76, 166, 166, 17, 79, 27]]
# cosCount =  9
# cosCount =  7
# [[68, 133, 127, 127, 119, 133, 16, 133, 85, 71], [127, 118, 127, 138, 155, 118, 127, 6, 155, 112]]

# %%
torch.save(model,"/content/data/model/Sean_train_1/check_point_manual_save.tar")

# %% [markdown]
# ### test

# %% [markdown]
# For loading automatically torch save state dict

# %%
test_model = Fast_R_cnn(roi_size=13,scaling_factor=float(51/840),rois_per_image=20,pretrained=PRE_TRAIN)

model_info = torch.load('/content/data/model/checkpoint.tar')

test_model.load_state_dict(model_info['state_dict'])

# %% [markdown]
# For loading manually torch.save model

# %%
test_model = torch.load("/content/data/model/Sean_train_1/auto_save.tar")

# %%
test_process(model=test_model, new_roi_proposal=NEW_ROI_PROPOSAL)
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/container.py:117: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# 串流輸出內容已截斷至最後 5000 行。
# ground_truth_xywh tensor([202., 385., 174., 120.], device='cuda:0')
# ground_truth_class:  tensor(2., device='cuda:0')
# identified_roi tensor([520.9344, 382.7079, 250.7465,  90.3843], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([646., 180., 190., 112.], device='cuda:0')
# ground_truth_class:  tensor(2., device='cuda:0')
# identified_roi tensor([524.7508, 367.4957, 247.0752,  90.2271], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([196., 117., 262.,  59.], device='cuda:0')
# ground_truth_class:  tensor(2., device='cuda:0')
# identified_roi tensor([518.4423, 376.2434, 248.3351,  90.6188], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([  1., 182., 144.,  88.], device='cuda:0')
# ground_truth_class:  tensor(2., device='cuda:0')
# identified_roi tensor([524.7508, 367.4957, 247.0752,  90.2271], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([338., 303., 186.,  83.], device='cuda:0')
# ground_truth_class:  tensor(2., device='cuda:0')
# identified_roi tensor([513.3223, 381.8763, 249.0548,  90.9412], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([  1., 182., 144.,  88.], device='cuda:0')
# ground_truth_class:  tensor(2., device='cuda:0')
# identified_roi tensor([524.7508, 367.4957, 247.0752,  90.2271], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([338., 303., 186.,  83.], device='cuda:0')
# ground_truth_class:  tensor(2., device='cuda:0')
# identified_roi tensor([524.7508, 367.4957, 247.0752,  90.2271], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([512., 195., 100.,  56.], device='cuda:0')
# ground_truth_class:  tensor(1., device='cuda:0')
# iou_score:  tensor([0.])
# identified_roi tensor([524.7508, 367.4957, 247.0752,  90.2271], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([296., 302., 208., 119.], device='cuda:0')
# ground_truth_class:  tensor(2., device='cuda:0')
# identified_roi tensor([535.6785, 386.4792, 249.8356,  89.9674], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([509.,   1., 154.,  83.], device='cuda:0')
# ground_truth_class:  tensor(2., device='cuda:0')
# identified_roi tensor([524.7508, 367.4957, 247.0752,  90.2271], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([296., 302., 208., 119.], device='cuda:0')
# ground_truth_class:  tensor(2., device='cuda:0')
# identified_roi tensor([518.4423, 376.2434, 248.3351,  90.6188], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([  1., 534., 208., 178.], device='cuda:0')
# ground_truth_class:  tensor(1., device='cuda:0')
# iou_score:  tensor([0.])
# identified_roi tensor([524.7508, 367.4957, 247.0752,  90.2271], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([296., 302., 208., 119.], device='cuda:0')
# ground_truth_class:  tensor(2., device='cuda:0')
# identified_roi tensor([529.8704, 372.3488, 247.8837,  90.0298], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([381., 140., 243., 158.], device='cuda:0')
# ground_truth_class:  tensor(2., device='cuda:0')
# identified_roi tensor([524.7508, 367.4957, 247.0752,  90.2271], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([208., 443., 156., 119.], device='cuda:0')
# ground_truth_class:  tensor(2., device='cuda:0')
# identified_roi tensor([524.7508, 367.4957, 247.0752,  90.2271], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([296., 302., 208., 119.], device='cuda:0')
# ground_truth_class:  tensor(2., device='cuda:0')
# identified_roi tensor([524.7508, 367.4957, 247.0752,  90.2271], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([208., 443., 156., 119.], device='cuda:0')
# ground_truth_class:  tensor(2., device='cuda:0')
# identified_roi tensor([535.6785, 386.4792, 249.8356,  89.9674], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([509.,   1., 154.,  83.], device='cuda:0')
# ground_truth_class:  tensor(2., device='cuda:0')
# identified_roi tensor([524.7508, 367.4957, 247.0752,  90.2271], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([381., 140., 243., 158.], device='cuda:0')
# ground_truth_class:  tensor(2., device='cuda:0')
# identified_roi tensor([522.7457, 370.9594, 247.6389,  90.3406], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([208., 443., 156., 119.], device='cuda:0')
# ground_truth_class:  tensor(2., device='cuda:0')
# identified_roi tensor([524.7508, 367.4957, 247.0752,  90.2271], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([691., 109.,  82.,  45.], device='cuda:0')
# ground_truth_class:  tensor(1., device='cuda:0')
# iou_score:  tensor([0.])
# identified_roi tensor([524.7508, 367.4957, 247.0752,  90.2271], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([683., 219.,  72.,  53.], device='cuda:0')
# ground_truth_class:  tensor(2., device='cuda:0')
# identified_roi tensor([524.7508, 367.4957, 247.0752,  90.2271], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([208., 443., 156., 119.], device='cuda:0')
# ground_truth_class:  tensor(2., device='cuda:0')
# identified_roi tensor([657.6246, 324.6049, 227.4057,  85.2675], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([663.,   1., 159.,  82.], device='cuda:0')
# ground_truth_class:  tensor(2., device='cuda:0')
# identified_roi tensor([524.7508, 367.4957, 247.0752,  90.2271], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([208., 443., 156., 119.], device='cuda:0')
# ground_truth_class:  tensor(2., device='cuda:0')
# identified_roi tensor([524.7508, 367.4957, 247.0752,  90.2271], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([296., 302., 208., 119.], device='cuda:0')
# ground_truth_class:  tensor(2., device='cuda:0')
# identified_roi tensor([522.6486, 370.9962, 247.6451,  90.3457], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([  1., 534., 208., 178.], device='cuda:0')
# ground_truth_class:  tensor(1., device='cuda:0')
# iou_score:  tensor([0.])
# identified_roi tensor([524.7508, 367.4957, 247.0752,  90.2271], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([631., 161.,  72.,  56.], device='cuda:0')
# ground_truth_class:  tensor(1., device='cuda:0')
# iou_score:  tensor([0.])
# iou_avg_score 0.000000 %
# avg_correct_class 15.000000 %
# loss_avg_this_batch:  0.8018480539321899
# identified_roi tensor([524.7508, 367.4957, 247.0752,  90.2271], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([298., 253., 219., 151.], device='cuda:0')
# ground_truth_class:  tensor(2., device='cuda:0')
# identified_roi tensor([524.7508, 367.4957, 247.0752,  90.2271], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([298., 253., 219., 151.], device='cuda:0')
# ground_truth_class:  tensor(2., device='cuda:0')
# identified_roi tensor([533.4532, 377.0069, 249.5012,  89.8314], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([ 34., 511., 193., 165.], device='cuda:0')
# ground_truth_class:  tensor(1., device='cuda:0')
# iou_score:  tensor([0.])
# identified_roi tensor([648.0294, 310.8162, 225.5703,  85.4311], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([731., 202.,  69.,  52.], device='cuda:0')
# ground_truth_class:  tensor(2., device='cuda:0')
# identified_roi tensor([655.2972, 318.9183, 226.6969,  85.2714], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([680.,  81., 152.,  65.], device='cuda:0')
# ground_truth_class:  tensor(1., device='cuda:0')
# iou_score:  tensor([0.])
# identified_roi tensor([648.0294, 310.8162, 225.5703,  85.4311], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([680.,  81., 152.,  65.], device='cuda:0')
# ground_truth_class:  tensor(1., device='cuda:0')
# iou_score:  tensor([0.])
# identified_roi tensor([524.7508, 367.4957, 247.0752,  90.2271], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([ 34., 511., 193., 165.], device='cuda:0')
# ground_truth_class:  tensor(1., device='cuda:0')
# iou_score:  tensor([0.])
# identified_roi tensor([524.7508, 367.4957, 247.0752,  90.2271], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([510., 251., 124.,  60.], device='cuda:0')
# ground_truth_class:  tensor(2., device='cuda:0')
# identified_roi tensor([535.6785, 386.4792, 249.8356,  89.9674], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([583.,   1., 257.,  72.], device='cuda:0')
# ground_truth_class:  tensor(2., device='cuda:0')
# identified_roi tensor([529.2188, 389.2182, 251.6809,  90.0634], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([583.,   1., 257.,  72.], device='cuda:0')
# ground_truth_class:  tensor(2., device='cuda:0')
# identified_roi tensor([532.8632, 378.7471, 248.7707,  89.9846], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([583.,   1., 257.,  72.], device='cuda:0')
# ground_truth_class:  tensor(2., device='cuda:0')
# identified_roi tensor([524.7508, 367.4957, 247.0752,  90.2271], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([680.,  81., 152.,  65.], device='cuda:0')
# ground_truth_class:  tensor(1., device='cuda:0')
# iou_score:  tensor([0.])
# identified_roi tensor([524.7508, 367.4957, 247.0752,  90.2271], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([298., 253., 219., 151.], device='cuda:0')
# ground_truth_class:  tensor(2., device='cuda:0')
# identified_roi tensor([535.6785, 386.4792, 249.8356,  89.9674], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([583.,   1., 257.,  72.], device='cuda:0')
# ground_truth_class:  tensor(2., device='cuda:0')
# identified_roi tensor([524.7508, 367.4957, 247.0752,  90.2271], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([298., 253., 219., 151.], device='cuda:0')
# ground_truth_class:  tensor(2., device='cuda:0')
# identified_roi tensor([531.3337, 380.3322, 250.0114,  89.9453], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([ 34., 511., 193., 165.], device='cuda:0')
# ground_truth_class:  tensor(1., device='cuda:0')
# iou_score:  tensor([0.])
# identified_roi tensor([524.7508, 367.4957, 247.0752,  90.2271], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([386., 190., 228.,  56.], device='cuda:0')
# ground_truth_class:  tensor(2., device='cuda:0')
# identified_roi tensor([657.6296, 324.6096, 227.4065,  85.2674], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor
], device='cuda:0')
# ground_truth_class:  tensor(2., device='cuda:0')
# identified_roi tensor([458.5363, 296.0487, 236.5238,  92.4608], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([200., 445., 296., 108.], device='cuda:0')
# ground_truth_class:  tensor(1., device='cuda:0')
# iou_score:  tensor([0.])
# identified_roi tensor([460.7863, 302.2787, 237.6944,  92.4124], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([200., 445., 296., 108.], device='cuda:0')
# ground_truth_class:  tensor(1., device='cuda:0')
# iou_score:  tensor([0.])
# identified_roi tensor([523.8298, 366.7517, 246.9477,  90.2618], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([424., 442., 250.,  65.], device='cuda:0')
# ground_truth_class:  tensor(2., device='cuda:0')
# identified_roi tensor([450.9125, 287.8769, 235.3531,  92.6998], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([200., 445., 296., 108.], device='cuda:0')
# ground_truth_class:  tensor(1., device='cuda:0')
# iou_score:  tensor([0.])
# identified_roi tensor([524.2461, 365.3678, 246.6187,  90.2344], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([424., 442., 250.,  65.], device='cuda:0')
# ground_truth_class:  tensor(2., device='cuda:0')
# identified_roi tensor([524.6505, 367.4150, 247.0555,  90.2312], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([298., 347., 242., 122.], device='cuda:0')
# ground_truth_class:  tensor(2., device='cuda:0')
# identified_roi tensor([524.7511, 367.4957, 247.0751,  90.2271], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([298., 347., 242., 122.], device='cuda:0')
# ground_truth_class:  tensor(2., device='cuda:0')
# identified_roi tensor([524.7508, 367.4957, 247.0752,  90.2271], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([298., 347., 242., 122.], device='cuda:0')
# ground_truth_class:  tensor(2., device='cuda:0')
# identified_roi tensor([522.6671, 381.3864, 250.1919,  90.3227], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([372.,  46., 185.,  88.], device='cuda:0')
# ground_truth_class:  tensor(2., device='cuda:0')
# identified_roi tensor([517.0219, 365.1369, 246.8439,  90.5125], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([298., 347., 242., 122.], device='cuda:0')
# ground_truth_class:  tensor(2., device='cuda:0')
# identified_roi tensor([524.7508, 367.4957, 247.0752,  90.2271], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([372.,  46., 185.,  88.], device='cuda:0')
# ground_truth_class:  tensor(2., device='cuda:0')
# identified_roi tensor([535.6794, 386.4783, 249.8355,  89.9673], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([372.,  46., 185.,  88.], device='cuda:0')
# ground_truth_class:  tensor(2., device='cuda:0')
# identified_roi tensor([518.7236, 366.6854, 247.0454,  90.4560], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([298., 347., 242., 122.], device='cuda:0')
# ground_truth_class:  tensor(2., device='cuda:0')
# identified_roi tensor([524.7508, 367.4957, 247.0752,  90.2271], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([298., 347., 242., 122.], device='cuda:0')
# ground_truth_class:  tensor(2., device='cuda:0')
# identified_roi tensor([524.7508, 367.4957, 247.0752,  90.2271], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([298., 347., 242., 122.], device='cuda:0')
# ground_truth_class:  tensor(2., device='cuda:0')
# identified_roi tensor([529.9355, 372.5014, 247.9050,  90.0290], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([372.,  46., 185.,  88.], device='cuda:0')
# ground_truth_class:  tensor(2., device='cuda:0')
# identified_roi tensor([524.7508, 367.4957, 247.0752,  90.2271], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([372.,  46., 185.,  88.], device='cuda:0')
# ground_truth_class:  tensor(2., device='cuda:0')
# identified_roi tensor([524.7049, 367.4442, 247.0647,  90.2288], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([298., 347., 242., 122.], device='cuda:0')
# ground_truth_class:  tensor(2., device='cuda:0')
# identified_roi tensor([524.5582, 367.3444, 247.0441,  90.2346], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([298., 347., 242., 122.], device='cuda:0')
# ground_truth_class:  tensor(2., device='cuda:0')
# identified_roi tensor([524.6124, 367.3748, 247.0516,  90.2322], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([298., 347., 242., 122.], device='cuda:0')
# ground_truth_class:  tensor(2., device='cuda:0')
# identified_roi tensor([532.8638, 378.7462, 248.7706,  89.9845], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([372.,  46., 185.,  88.], device='cuda:0')
# ground_truth_class:  tensor(2., device='cuda:0')
# identified_roi tensor([524.7508, 367.4957, 247.0752,  90.2271], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([298., 347., 242., 122.], device='cuda:0')
# ground_truth_class:  tensor(2., device='cuda:0')
# identified_roi tensor([522.5842, 369.8219, 247.4594,  90.3290], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([298., 347., 242., 122.], device='cuda:0')
# ground_truth_class:  tensor(2., device='cuda:0')
# identified_roi tensor([524.0344, 366.7061, 246.9579,  90.2481], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([298., 347., 242., 122.], device='cuda:0')
# ground_truth_class:  tensor(2., device='cuda:0')
# identified_roi tensor([523.8819, 366.5935, 246.9344,  90.2544], device='cuda:0')
# identified_roi_class tensor(1, device='cuda:0')
# ground_truth_xywh tensor([298., 347., 242., 122.], device='cuda:0')
# ground_truth_class:  tensor(2., device='cuda:0')
# iou_avg_score 0.000000 %
# avg_correct_class 22.500000 %
# loss_aver: 0.709511

# %% [markdown]
# ##Data visulize

# %%
test_model.eval()
# Out:
# Fast_R_cnn(
#   (alexnet): Sequential(
#     (0): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#       (1): ReLU(inplace=True)
#       (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (4): ReLU(inplace=True)
#       (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (7): ReLU(inplace=True)
#       (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (9): ReLU(inplace=True)
#       (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (11): ReLU(inplace=True)
#       (12): Identity()
#     )
#   )
#   (ROI_head): Sequential(
#     (0): Linear(in_features=43264, out_features=21632, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=21632, out_features=10816, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Linear(in_features=10816, out_features=3000, bias=True)
#   )
#   (classficiation_label): Sequential(
#     (0): Linear(in_features=3000, out_features=3, bias=True)
#     (1): Softmax(dim=None)
#   )
#   (fc_before_regressor): Sequential(
#     (0): Linear(in_features=3000, out_features=4, bias=True)
#     (1): ReLU()
#   )
#   (regressor): Sequential(
#     (0): Linear(in_features=3000, out_features=4, bias=True)
#   )
# )

# %%
def get_test_image(FileName,folders):
  img_info=dict()
  for folder in folders:
        output = []
        with open('data/bbox_'+folder+'.csv') as f:
          idx = -1
          last_name = 'none'
          for line in f.read().splitlines():
            filename, _, _, _, *box = line.split(',')
            if filename == 'filename':
              continue
            if filename==last_name:
              continue
            else:
              idx = idx + 1
              last_name=filename
            
            if filename in target_fileName:
              output.append(idx)
        img_info[folder]=output
  return img_info

# %%
target_fileName = ["HS_H08_20160313_0330_25.41_122.35.npy",
          "HS_H08_20171122_1600_32.56_133.1.npy",
          "HS_H08_20180312_1730_27.06_106.49.npy",
          "HS_H08_20190105_0430_32.541389_114.077778.npy"]
target_folder=['test','train','val']
image_info=get_test_image(target_fileName,target_folder)

# %%
imgs = []
test_idx = image_info.get("test")[0]
train_idx = image_info.get("train")[0]
val_idxs = image_info.get("val")

imgs, boxes, turbs, rois = test[test_idx]

size = 20
#proposed_rois = genRoIsperImg(imgs, 10)
roi_index_list = mini_batch_sampling([rois], size, 0.5, True)

gt_roi_labels = torch.ones([len(roi_index_list)*size]) #20 = batch*rois_per_image
gt_roi_coord = torch.ones([len(roi_index_list)*size,4])
roi_list = torch.zeros([size,5], dtype=torch.float32) 
for i in range(len(roi_index_list)):
  for j in range(len(roi_index_list[i])):
    roi_list[i*size+j,:] = torch.tensor(np.insert(rois[roi_index_list[i][j]][0], 0, i))
    gt_roi_labels[i*size+j] = torch.tensor(rois[roi_index_list[i][j]][1]["gt_box_class"])
    x1y1x2y2 = torch.tensor(rois[roi_index_list[i][j]][1]["gt_box_coord"])
    x1y1wh = torch.tensor([x1y1x2y2[0],x1y1x2y2[1],x1y1x2y2[2]-x1y1x2y2[0],x1y1x2y2[3]-x1y1x2y2[1]])
    gt_roi_coord[i*size+j] = x1y1wh

roi_list = roi_list.cuda()
gt_roi_labels = gt_roi_labels.cuda()
gt_roi_coord = gt_roi_coord.cuda()

imgs_batch = torch.tensor([np.array(imgs)])
imgs_batch = imgs_batch.cuda()
result_class_score, result_coord, p_value, d_value = test_model(images_data = imgs_batch, roi_list= roi_list, batch_size = len(roi_index_list))
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/container.py:117: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)

# %%
predicted_turbs = torch.argmax(result_class_score, dim=1)
inp = imgs.numpy().transpose((1, 2, 0))
mean = np.array([0.485, 0.456, 0.406])
std = np.array([0.229, 0.224, 0.225])
inp = std * inp + mean
imshow(inp, xywh_to_x1y1x2y2(result_coord.cpu()), predicted_turbs, VMIN=0.76) #select VMIN from 0.7-0.8
# Out:
# (840, 840)

# %%
imshow(inp, boxes, turbs, VMIN=0.76)
# Out:
# (840, 840)

# %%
imgs, boxes, turbs, rois = train[train_idx]

size = 20
#proposed_rois = genRoIsperImg(imgs, 10)
roi_index_list = mini_batch_sampling([rois], size, 0.5, True)

gt_roi_labels = torch.ones([len(roi_index_list)*size]) #20 = batch*rois_per_image
gt_roi_coord = torch.ones([len(roi_index_list)*size,4])
roi_list = torch.zeros([size,5], dtype=torch.float32) 
for i in range(len(roi_index_list)):
  for j in range(len(roi_index_list[i])):
    roi_list[i*size+j,:] = torch.tensor(np.insert(rois[roi_index_list[i][j]][0], 0, i))
    gt_roi_labels[i*size+j] = torch.tensor(rois[roi_index_list[i][j]][1]["gt_box_class"])
    x1y1x2y2 = torch.tensor(rois[roi_index_list[i][j]][1]["gt_box_coord"])
    x1y1wh = torch.tensor([x1y1x2y2[0],x1y1x2y2[1],x1y1x2y2[2]-x1y1x2y2[0],x1y1x2y2[3]-x1y1x2y2[1]])
    gt_roi_coord[i*size+j] = x1y1wh

roi_list = roi_list.cuda()
gt_roi_labels = gt_roi_labels.cuda()
gt_roi_coord = gt_roi_coord.cuda()

imgs_batch = torch.tensor([np.array(imgs)])
imgs_batch = imgs_batch.cuda()
result_class_score, result_coord, p_value, d_value = test_model(images_data = imgs_batch, roi_list= roi_list, batch_size = len(roi_index_list))
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/container.py:117: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)

# %%
inp = imgs.numpy().transpose((1, 2, 0))
mean = np.array([0.485, 0.456, 0.406])
std = np.array([0.229, 0.224, 0.225])
inp = std * inp + mean
imshow(inp, xywh_to_x1y1x2y2(result_coord.cpu()), predicted_turbs, VMIN=0.76) #select VMIN from 0.7-0.8
# Out:
# (840, 840)

# %%
imshow(inp, boxes, turbs, VMIN=0.76)
# Out:
# (840, 840)

# %%
imgs, boxes, turbs, rois = val[val_idxs[0]]

size = 20
#proposed_rois = genRoIsperImg(imgs, 10)
roi_index_list = mini_batch_sampling([rois], size, 0.5, True)

gt_roi_labels = torch.ones([len(roi_index_list)*size]) #20 = batch*rois_per_image
gt_roi_coord = torch.ones([len(roi_index_list)*size,4])
roi_list = torch.zeros([size,5], dtype=torch.float32) 
for i in range(len(roi_index_list)):
  for j in range(len(roi_index_list[i])):
    roi_list[i*size+j,:] = torch.tensor(np.insert(rois[roi_index_list[i][j]][0], 0, i))
    gt_roi_labels[i*size+j] = torch.tensor(rois[roi_index_list[i][j]][1]["gt_box_class"])
    x1y1x2y2 = torch.tensor(rois[roi_index_list[i][j]][1]["gt_box_coord"])
    x1y1wh = torch.tensor([x1y1x2y2[0],x1y1x2y2[1],x1y1x2y2[2]-x1y1x2y2[0],x1y1x2y2[3]-x1y1x2y2[1]])
    gt_roi_coord[i*size+j] = x1y1wh

roi_list = roi_list.cuda()
gt_roi_labels = gt_roi_labels.cuda()
gt_roi_coord = gt_roi_coord.cuda()

imgs_batch = torch.tensor([np.array(imgs)])
imgs_batch = imgs_batch.cuda()
result_class_score, result_coord, p_value, d_value = test_model(images_data = imgs_batch, roi_list= roi_list, batch_size = len(roi_index_list))
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/container.py:117: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)

# %%
inp = imgs.numpy().transpose((1, 2, 0))
mean = np.array([0.485, 0.456, 0.406])
std = np.array([0.229, 0.224, 0.225])
inp = std * inp + mean
imshow(inp, xywh_to_x1y1x2y2(result_coord.cpu()), predicted_turbs, VMIN=0.76) #select VMIN from 0.7-0.8
# Out:
# (840, 840)

# %%
imshow(inp, boxes, turbs, VMIN=0.76)
# Out:
# (840, 840)

# %%
imgs, boxes, turbs, rois = val[val_idxs[1]]

size = 20
#proposed_rois = genRoIsperImg(imgs, 10)
roi_index_list = mini_batch_sampling([rois], size, 0.5, True)

gt_roi_labels = torch.ones([len(roi_index_list)*size]) #20 = batch*rois_per_image
gt_roi_coord = torch.ones([len(roi_index_list)*size,4])
roi_list = torch.zeros([size,5], dtype=torch.float32) 
for i in range(len(roi_index_list)):
  for j in range(len(roi_index_list[i])):
    roi_list[i*size+j,:] = torch.tensor(np.insert(rois[roi_index_list[i][j]][0], 0, i))
    gt_roi_labels[i*size+j] = torch.tensor(rois[roi_index_list[i][j]][1]["gt_box_class"])
    x1y1x2y2 = torch.tensor(rois[roi_index_list[i][j]][1]["gt_box_coord"])
    x1y1wh = torch.tensor([x1y1x2y2[0],x1y1x2y2[1],x1y1x2y2[2]-x1y1x2y2[0],x1y1x2y2[3]-x1y1x2y2[1]])
    gt_roi_coord[i*size+j] = x1y1wh

roi_list = roi_list.cuda()
gt_roi_labels = gt_roi_labels.cuda()
gt_roi_coord = gt_roi_coord.cuda()

imgs_batch = torch.tensor([np.array(imgs)])
imgs_batch = imgs_batch.cuda()
result_class_score, result_coord, p_value, d_value = test_model(images_data = imgs_batch, roi_list= roi_list, batch_size = len(roi_index_list))
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/container.py:117: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)

# %%
inp = imgs.numpy().transpose((1, 2, 0))
mean = np.array([0.485, 0.456, 0.406])
std = np.array([0.229, 0.224, 0.225])
inp = std * inp + mean
imshow(inp, xywh_to_x1y1x2y2(result_coord.cpu()), predicted_turbs, VMIN=0.76) #select VMIN from 0.7-0.8
# Out:
# (840, 840)

# %%
imshow(inp, boxes, turbs, VMIN=0.76)
# Out:
# (840, 840)
